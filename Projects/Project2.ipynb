# %% [markdown]
# dataset containing: price of single car model in $1000s with age of car and number of miles driven
# represented as: 2003 Honda Civic with 75,670 miles that’s selling for $5,685 would be coded as age=15, miles=75.7, price=5.7.
