# %%
# funcname(input1, input2)

# concatenate / vector
x = c(1,3,2,5)
y = c(1,3,2,5)
x

# ?funcname # opens documentation on function

# add 2 sets of same length numbers (paired by index)
length(x)
length(y)
x+y

# same as terminal
ls()
rm(x,y)
ls()

rm(list=ls()) # rfemove all at once
