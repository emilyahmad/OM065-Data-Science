# %%
library(class)
knn(...) # lives in class, runs knn

# draw training & test, sample() not best command
training = sample(150,50)
test = sample(150,50)

# knn(training[rows, cols], nw[r,c]
knn.result = knn(iris[train, -5], iris[test,-5], iris$Species[train])
table(knn.result, iris$Species[test]) # generates confusion matrix

# accuracy = correctly / total : 48/50, 96% (add up diagonal elements)

# cool: try to visualize in 4d space

# to optimize k, for loop k (1 : N), store in a vector & find value for max accuracy
